# %%
from section_efficace import create_cross_section

folder = 'output_dir'
results = create_cross_section(folder)
# Out:
# (2000.0, 250.0, 900.0, 267.692499, -914.423461, 267.866526, 920.329068, {('1000037', '1000023'): ('3.7994237e-04', '4.1898669e-04'), ('-1000037', '1000023'): ('1.1194093e-04', '1.3363171e-04'), ('1000037', '1000025'): ('3.8367729e-04', '4.2302655e-04'), ('-1000037', '1000025'): ('1.1298856e-04', '1.3487046e-04'), ('1000037', '-1000037'): ('2.5446281e-04', '2.9402260e-04'), ('1000025', '1000023'): ('2.3260876e-04', '2.6677702e-04')})

# %%
result_1000 = [result for result in results if result[1] == 500.0]

# %%
import matplotlib.pyplot as plt

liste = [(result[2], result[3]) for result in result_1000]
liste_sorted = sorted(liste, key = lambda tup:tup[0])

mu = [x[0] for x in liste_sorted]
N1 = [x[1] for x in liste_sorted]
plt.scatter(mu,N1)
